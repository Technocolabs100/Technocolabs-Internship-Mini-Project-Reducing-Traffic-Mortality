# %%
### first data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
 ##Read in and get an overview of the data
miles_data=pd.read_csv('../input/miles-data/milll.csv',sep="|",index_col="state")
miles_data.head()
# Out:
#             million_miles_annually
# state
# Alabama                      64914
# Alaska                        4593
# Arizona                      59575
# Arkansas                     32953
# California                  320784

# %%
print(miles_data)
# Out:
#                       million_miles_annually
# state
# Alabama                                64914
# Alaska                                  4593
# Arizona                                59575
# Arkansas                               32953
# California                            320784
# Colorado                               46606
# Connecticut                            31197
# Delaware                                9028
# District of Columbia                    3568
# Florida                               191855
# Georgia                               108454
# Hawaii                                 10066
# Idaho                                  15937
# Illinois                              103234
# Indiana                                76485
# Iowa                                   31274
# Kansas                                 30021
# Kentucky                               48061
# Louisiana                              46513
# Maine                                  14248
# ...

# %%
accident_data=pd.read_csv("../input/accident-data/data1111.csv",sep="|",index_col="state",skiprows=9)
accident_data.head()
# Out:
#             drvr_fatl_col_bmiles  perc_fatl_speed  perc_fatl_alcohol  \
# state
# Alabama                     18.8               39                 30
# Alaska                      18.1               41                 25
# Arizona                     18.6               35                 28
# Arkansas                    22.4               18                 26
# California                  12.0               35                 28
#
#             perc_fatl_1st_time
# state
# Alabama                     80
# Alaska                      94
# Arizona                     96
# Arkansas                    95
# California                  89

# %%
accident_data.describe()
# Out:
#        drvr_fatl_col_bmiles  perc_fatl_speed  perc_fatl_alcohol  \
# count             51.000000        51.000000          51.000000
# mean              15.790196        31.725490          30.686275
# std                4.122002         9.633438           5.132213
# min                5.900000        13.000000          16.000000
# 25%               12.750000        23.000000          28.000000
# 50%               15.600000        34.000000          30.000000
# 75%               18.500000        38.000000          33.000000
# max               23.900000        54.000000          44.000000
#
#        perc_fatl_1st_time
# count            51.00000
# mean             88.72549
# std               6.96011
# min              76.00000
# 25%              83.50000
# 50%              88.00000
# 75%              95.00000
# max             100.00000

# %%
##combining the two data for better manipulation and understanding
global_data=accident_data.join(miles_data)
global_data.head()
# Out:
#             drvr_fatl_col_bmiles  perc_fatl_speed  perc_fatl_alcohol  \
# state
# Alabama                     18.8               39                 30
# Alaska                      18.1               41                 25
# Arizona                     18.6               35                 28
# Arkansas                    22.4               18                 26
# California                  12.0               35                 28
#
#             perc_fatl_1st_time  million_miles_annually
# state
# Alabama                     80                   64914
# Alaska                      94                    4593
# Arizona                     96                   59575
# Arkansas                    95                   32953
# California                  89                  320784

# %%
global_data.describe()
# Out:
#        drvr_fatl_col_bmiles  perc_fatl_speed  perc_fatl_alcohol  \
# count             51.000000        51.000000          51.000000
# mean              15.790196        31.725490          30.686275
# std                4.122002         9.633438           5.132213
# min                5.900000        13.000000          16.000000
# 25%               12.750000        23.000000          28.000000
# 50%               15.600000        34.000000          30.000000
# 75%               18.500000        38.000000          33.000000
# max               23.900000        54.000000          44.000000
#
#        perc_fatl_1st_time  million_miles_annually
# count            51.00000               51.000000
# mean             88.72549            57851.019608
# std               6.96011            59898.414088
# min              76.00000             3568.000000
# 25%              83.50000            17450.000000
# 50%              88.00000            46606.000000
# ...

# %%
col=global_data.columns
sns.histplot(global_data[col[0]])
# Out:
# <AxesSubplot:xlabel='drvr_fatl_col_bmiles', ylabel='Count'>

# %%
plt.hist(global_data[col[0]],bins=100,alpha=0.5,label=col[0])

plt.xlabel(col[0],size=14)
plt.ylabel("Count",size=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(global_data[col[1]],bins=100,alpha=0.5,label=col[0])

plt.xlabel(col[1],size=14)
plt.ylabel("Count",size=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(global_data[col[2]],bins=100,alpha=0.5,label=col[3])

plt.xlabel(col[3],size=14)
plt.ylabel("Count",size=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(global_data[col[3]],bins=100,alpha=0.5,label=col[3])


plt.xlabel(col[4],size=14)
plt.ylabel("Count",size=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(global_data[col[4]],bins=100,alpha=0.5,label=col[4])
plt.xlabel(col[4],size=14)
plt.ylabel("Count",size=14)
plt.show()

# %%
plt.figure(figsize=(18,9))
sns.barplot(y=global_data.index,x=global_data[col[0]])
# Out:
# <AxesSubplot:xlabel='drvr_fatl_col_bmiles', ylabel='state'>

# %%
###display a barchart for all the columns of our merged data fora better undestanding of data
fig, axs = plt.subplots(ncols=5)
fig.set_size_inches(20, 10)
fig.subplots_adjust(hspace=100, wspace=0.9)

sns.barplot(y=global_data.index,x=global_data[col[0]],ax=axs[0])
sns.barplot(y=global_data.index,x=global_data[col[1]],ax=axs[1])
sns.barplot(y=global_data.index,x=global_data[col[2]],ax=axs[2])
sns.barplot(y=global_data.index,x=global_data[col[3]],ax=axs[3])
sns.barplot(y=global_data.index,x=global_data[col[4]],ax=axs[4])
# Out:
# <AxesSubplot:xlabel='million_miles_annually', ylabel='state'>

# %% [markdown]
# it would be good to have a scatteroplots that made in relation the columns of road_accident data these scatter would present the realation between the number of fatal accident and the oder labels of th road_accident data
# it would help to visualise th realation between variables

# %%
fig,axs=plt.subplots(ncols=3)
fig.set_size_inches(20,5)
fig.subplots_adjust(hspace=100,wspace=0.9)
for i in range(1,4):
    sns.scatterplot(x=global_data[col[i]],y=global_data[col[0]],ax=axs[i-1])

# %% [markdown]
# it would be good to have a scatteroplots that made in relation the columns of road_accident data these scatter would pr
# it would help to visualise th realation between variables

# %%
fig,axs=plt.subplots(ncols=4)
fig.set_size_inches(20,5)
fig.subplots_adjust(hspace=100,wspace=0.9)
for i in range(0,4):
    sns.scatterplot(x=global_data[col[i]],y=global_data[col[4]],ax=axs[i])

# %% [markdown]
# Now we will mesurethe correlation between the variables of our raod_accident data

# %%
import numpy as np
from scipy.stats import pearsonr

for i in range(0,4):
    for j in range(i+1,4):
        r,_=pearsonr(global_data[col[i]],global_data[col[j]])
        print("the correlation between     "+col[i]+"   and     "+col[j])
        print(r)
        print("\n\n\n")
# Out:
# the correlation between     drvr_fatl_col_bmiles   and     perc_fatl_speed
# -0.02908014591399068
#
#
#
#
# the correlation between     drvr_fatl_col_bmiles   and     perc_fatl_alcohol
# 0.19942634378011184
#
#
#
#
# the correlation between     drvr_fatl_col_bmiles   and     perc_fatl_1st_time
# -0.017941876874043666
#
#
#
#
# the correlation between     perc_fatl_speed   and     perc_fatl_alcohol
# 0.28624417148140197
#
#
#
#
# the correlation between     perc_fatl_speed   and     perc_fatl_1st_time
# 0.014066221138544107
#
#
#
#
# the correlation between     perc_fatl_alcohol   and     perc_fatl_1st_time
# -0.24545505951209245

# %% [markdown]
# the correlation between     drvr_fatl_col_bmiles   and     perc_fatl_speed is : week

# %% [markdown]
# the correlation between     drvr_fatl_col_bmiles   and     perc_fatl_alcohol is : week

# %% [markdown]
# the correlation between     drvr_fatl_col_bmiles   and     perc_fatl_1st_time is : week

# %% [markdown]
# the correlation between     perc_fatl_speed   and     perc_fatl_alcohol is : medium

# %% [markdown]
#  the correlation between     perc_fatl_speed   and     perc_fatl_1st_time is : week

# %% [markdown]
# the correlation between     perc_fatl_alcohol   and     perc_fatl_1st_time is : medium

# %%
### multivariate linear regression
from sklearn import linear_model
X=global_data[[col[1],col[2],col[3]]]
Y=global_data[[col [0]]]
reg=linear_model.LinearRegression()
reg.fit(X,Y)

print ("coefficients : ",reg.coef_) 
print ("Intercept : ",reg.intercept_)
# Out:
# coefficients :  [[-0.04180041  0.19086404  0.02473301]]
# Intercept :  [9.06498048]

# %% [markdown]
# **When comparing the regression coefficients with the correlation coefficients, we see that they are slightly different**
# also we can see that for the first two coefficients they have the same signa as the corrlation coefficients but the third coefficients have the oposite sign of the correlation coefficient so we can say that we have a masking relation ship between drvr_fatl_col_bmiles   and     perc_fatl_1st_time
#
# So after building this multivaraite regression we found that the relation that would be built between the variables is
# Y=-0.04180041X1+0.19086404 X2 + 0.02473301 X3 +9.06498048
#
# And Xi ares the

# %%
###Perform PCA on standardized data

import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
###data standarsation
scl=StandardScaler()
scl.fit(global_data[[col[1],col[2],col[3]]])
scaled_data=scl.transform(global_data[[col[1],col[2],col[3]]])
scaled=pd.DataFrame(scaled_data,columns=['perc_fatl_speed','perc_fatl_alcohol','perc_fatl_1st_time'],index=global_data.index)
print(scaled)
# Out:
#                       perc_fatl_speed  perc_fatl_alcohol  perc_fatl_1st_time
# state
# Alabama                      0.762645          -0.135050           -1.266117
# Alaska                       0.972321          -1.118982            0.765361
# Arizona                      0.343293          -0.528623            1.055572
# Arkansas                    -1.438953          -0.922196            0.910466
# California                   0.343293          -0.528623            0.039833
# Colorado                     0.552969          -0.528623            0.910466
# Connecticut                  1.496511           1.045670           -0.975906
# Delaware                     0.657807          -0.135050            1.490888
# District of Columbia         0.238455          -0.725409            1.635994
# Florida                     -1.124439          -0.331836            0.765361
# Georgia                     -1.334115          -1.118982            0.620255
# ...

# %% [markdown]
# **we make on the same scale the three feature that would be used for model training ******

# %%
###PCA application
principal_features=PCA(n_components=3)
principal_features.fit(scaled_data)
pca_data=principal_features.transform(scaled_data)
pca=pd.DataFrame(pca_data,columns=['perc_fatl_speed','perc_fatl_alcohol','perc_fatl_1st_time'],index=global_data.index)
print(pca)
print(pca.shape)
# Out:
#                       perc_fatl_speed  perc_fatl_alcohol  perc_fatl_1st_time
# state
# Alabama                      0.884639           0.464211            1.097652
# Alaska                      -0.625299          -1.220247            0.950424
# Arizona                     -0.671696          -1.027863            0.062021
# Arkansas                    -1.839546           0.239910           -0.555421
# California                  -0.211743          -0.256667            0.536811
# Colorado                    -0.493905          -1.054144            0.242906
# Connecticut                  1.988056          -0.226978            0.530546
# Delaware                    -0.419847          -1.560808           -0.247592
# District of Columbia        -1.130991          -1.401442           -0.127957
# Florida                     -1.184444           0.148770           -0.731585
# Georgia                     -1.792512           0.390903           -0.225380
# ...

# %%
principal_features.components_
# Out:
# array([[ 0.53455662,  0.71358084, -0.45282624],
#        [-0.65077841,  0.00570541, -0.75924627],
#        [ 0.53920003, -0.70054967, -0.46743287]])

# %%
###visualisation of the scaled data after the application f the pca
###Visualize the first two principal components
plt.figure(figsize=(14,8))
plt.scatter(pca_data[:,0],pca_data[:,1],cmap='plasma')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(16,8))
axis = fig.add_subplot(111, projection='3d')
axis.scatter(pca_data[:,0],pca_data[:,1],pca_data[:,2],cmap='plasma')
fig.add_axes(axis)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
###Find clusters of similar states in the data
from sklearn.cluster import KMeans

modl=KMeans(n_clusters=2)
modl.fit(scaled_data)
result=modl.predict(scaled_data)
plt.figure(figsize=(16,8))
plt.scatter(scaled_data[:,0],scaled_data[:,1],c=result, s=50, cmap='viridis')
##we can visualize the centers of our cluster
centers =modl.cluster_centers_
plt.scatter(centers[:,0],centers[:,1],c='black',s=200,alpha=0.5)

# %% [markdown]
# **we can see easily that having two clusters doen't represent effictivly our data and we still need to have more clusters**

# %% [markdown]
# **Now we will use the elbow mthode to find the best number of clusters that we would have**

# %%
distortions=[]
for i in range(1,10):
    mod=KMeans(n_clusters=i)
    mod.fit(scaled_data)
    distortions.append(mod.inertia_)

print(distortions)
# Out:
# [153.0, 101.59081556315158, 72.39839077808163, 57.80472652795009, 46.10580914149266, 39.617175316296354, 32.9511319567265, 29.76776551453275, 26.21780971745936]

# %%
plt.figure(figsize=(19,8))
K=range(1,10)
plt.plot(K,distortions)

# %% [markdown]
# **We can see that from K=3 the distorion kept decreasng in almost a linear way
# So, the elbow is 3
# > the optimal number of clusters is 3

# %%
from sklearn.cluster import KMeans

plt.figure(figsize=(19,8))
clusters=KMeans(n_clusters=3)
clusters.fit(scaled_data)
marks=clusters.predict(scaled_data)

plt.scatter(scaled_data[:,0],scaled_data[:,2],c=marks,s=50,cmap='viridis')

cens=clusters.cluster_centers_
plt.scatter(cens[:,0],cens[:,1],c='Red',s=200,alpha=0.5)

# %%
###Visualize the feature differences between the clusters
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(19,8))
ax = plt.axes(projection='3d')
ax.scatter3D(global_data[col[1]], global_data[col[2]], global_data[col[3]], c=marks, cmap='viridis')
ax.set_xlabel(col[1])
ax.set_ylabel(col[1])
ax.set_zlabel(col[1]);
plt.title('Visualize the feature differences between the clusters')
# Out:
# Text(0.5, 0.92, 'Visualize the feature differences between the clusters')

# %% [markdown]
# so we are visualising our clusters from the non-scaled data

# %%
###Compute the number of accidents within each cluster
##combining the two data for better manipulation and understanding
global_data=accident_data.join(miles_data)
global_data.head()
# Out:
#             drvr_fatl_col_bmiles  perc_fatl_speed  perc_fatl_alcohol  \
# state
# Alabama                     18.8               39                 30
# Alaska                      18.1               41                 25
# Arizona                     18.6               35                 28
# Arkansas                    22.4               18                 26
# California                  12.0               35                 28
#
#             perc_fatl_1st_time  million_miles_annually
# state
# Alabama                     80                   64914
# Alaska                      94                    4593
# Arizona                     96                   59575
# Arkansas                    95                   32953
# California                  89                  320784

# %%
global_data['clusters']=marks ##marks=clusters.predict(scaled_data)
global_data.tail()
# Out:
#                drvr_fatl_col_bmiles  perc_fatl_speed  perc_fatl_alcohol  \
# state
# Virginia                       12.7               19                 27
# Washington                     10.6               42                 33
# West Virginia                  23.8               34                 28
# Wisconsin                      13.8               36                 33
# Wyoming                        17.4               42                 32
#
#                perc_fatl_1st_time  million_miles_annually  clusters
# state
# Virginia                       88                   80974         0
# Washington                     86                   56955         1
# West Virginia                  87                   18963         2
# Wisconsin                      84                   58554         1
# Wyoming                        90                    9245         1

# %%
import seaborn as sns
plt.figure(figsize=(18,7))
global_data['total accident']=global_data['drvr_fatl_col_bmiles']*global_data['million_miles_annually']/10000
used_data=global_data.loc[:,['total accident','clusters']]
sns.violinplot(data=used_data,x='clusters',y='total accident')
plt.show()

# %% [markdown]
# from the violin plots we could say that the cluster 1 is the onne that should have more interset and controll from the authorities because it contains states that have a high range of fatal accidents , also  it contains an importantt number of sate that have a similar number of fatal accident
